# %%
import warnings
warnings.filterwarnings('ignore')

from fastai.vision import *
from fastai.callbacks import *
from knockknock import email_sender

# %%
path = Path('.').absolute()
data_path = path / 'data256' / 'train'
model_path = path / 'models'

# %%
sz = 256
lr = defaults.lr
bs = 32

# %%
def open_div(self, fn):
    return open_mask(fn, after_open=self.after_open, div=True)

SegmentationLabelList.open = open_div

# %%
stats = ([0.491102, 0.491102, 0.491102], [0.24893701, 0.24893701, 0.24893701])

def label_func(o):
    return str(o).replace('train', 'masks')

data = (SegmentationItemList.from_folder(data_path)
        .split_by_rand_pct(0.2)
        .label_from_func(label_func, classes=[0, 1])
        .transform(get_transforms(), size=sz, tfm_y=True)
        .databunch(bs=bs)
        .normalize(stats))

# %%
data.show_batch()

# %%
learn = unet_learner(data, 
                     models.resnet34, 
                     metrics=[dice],
                     model_dir=model_path,
                     callback_fns=[partial(SaveModelCallback, monitor='dice', name='best_dice')],
                    ).to_fp16()

# %%
@email_sender(recipient_emails=["yyang@hbku.edu.qa"], sender_email="hbkubot@gmail.com")
def train(learn, name, lr, n_epoch=5):
    learn.fit_one_cycle(n_epoch, lr)
    learn.save(name)
    return name

# %%
train(learn, 'stage_1', lr=lr)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.022223</td>
#       <td>0.014356</td>
#       <td>0.796452</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.014964</td>
#       <td>0.014010</td>
#       <td>0.796452</td>
#       <td>01:54</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.012735</td>
#       <td>0.010625</td>
#       <td>0.782242</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.011185</td>
#       <td>0.009969</td>
#       <td>0.785828</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.010279</td>
#       <td>0.009738</td>
#       <td>0.793049</td>
#       <td>01:55</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with dice value: 0.7964519262313843.
# 'stage_1'

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='65' class='' max='267', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       24.34% [65/267 00:29<01:31 0.0513]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 1.58E-06
# Min loss divided by 10: 1.00E-04

# %%
lr = 1e-4
train(learn, 'stage_2', lr=slice(lr/100, lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.013225</td>
#       <td>0.012121</td>
#       <td>0.785444</td>
#       <td>02:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.011239</td>
#       <td>0.010965</td>
#       <td>0.794535</td>
#       <td>02:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.011020</td>
#       <td>0.010290</td>
#       <td>0.794973</td>
#       <td>02:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.009721</td>
#       <td>0.010030</td>
#       <td>0.796553</td>
#       <td>02:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.009456</td>
#       <td>0.009689</td>
#       <td>0.796299</td>
#       <td>02:03</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with dice value: 0.7854436635971069.
# Better model found at epoch 1 with dice value: 0.794535219669342.
# Better model found at epoch 2 with dice value: 0.7949728965759277.
# Better model found at epoch 3 with dice value: 0.7965532541275024.
# 'stage_2'

# %%
learn.show_results()
