# %%
# !wget https://gist.githubusercontent.com/FedeMiorelli/640bbc66b2038a14802729e609abfe89/raw/1aa7f0d0fdc1d3d4cc21b2e70991edd55e6f8485/turbo_colormap_mpl.py

# %%
from PIL import Image
from pathlib import Path
from matplotlib import pyplot as plt
import turbo_colormap_mpl

# %%
path = Path('.')

# %%
# fn = path / 'chest_xray/val/NORMAL/NORMAL2-IM-1427-0001.jpeg'
fn = path / 'chest_xray/val/PNEUMONIA/person1946_bacteria_4874.jpeg'

# %%
img = Image.open(fn)

# %%
plt.imshow(img, cmap='bone')

# %%
plt.imshow(img, cmap='turbo')

# %%
plt.imshow(img, cmap='jet')

# %%
plt.imshow(img, cmap='inferno')

# %%
plt.imshow(img, cmap='viridis')

# %%
plt.imshow(img, cmap='gist_ncar')

# %%
plt.imshow(img, cmap='gist_rainbow')
